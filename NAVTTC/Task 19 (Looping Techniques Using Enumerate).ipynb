# %% [markdown]
# ### Looping Techniques Using Enumerate

# %%
words = ['The', 'Big', 'Bang', 'Theory']

for index, value in enumerate(words):
    print(index, value)
# Out:
# 0 The
# 1 Big
# 2 Bang
# 3 Theory

# %% [markdown]
# #### Looping Techniques Using Zip()

# %%
names = ['Leo', 'Kendall', 'Harry']
ages = (24, 27, 25)

for name, age in zip(names, ages):
    print(f"Name: {name}, Age: {age}")
# Out:
# Name: Leo, Age: 24
# Name: Kendall, Age: 27
# Name: Harry, Age: 25

# %% [markdown]
# #### Looping Techniques Using items()

# %%
p1 = {'Washington': 'First', 'Lincoln': 'Emancipator', 'Roosevelt': 'Trust-Buster'}

for name, title in p1.items():
    print(name, title)
# Out:
# Washington First
# Lincoln Emancipator
# Roosevelt Trust-Buster

# %% [markdown]
# #### Looping Techniques Using sorted()

# %%
num = [1, 3, 5, 6, 2, 1, 3]

print("Sorted list:")
for n in sorted(num):
    print(n, end=" ")

print("\nSorted list without duplicates:")
for n in sorted(set(num)):
    print(n, end=" ")
# Out:
# Sorted list:
# 1 1 2 3 3 5 6
# Sorted list without duplicates:
# 1 2 3 5 6

# %% [markdown]
# #### Looping Techniques Using reversed()

# %%
num = [1, 3, 5, 6, 2, 1, 3]

for n in reversed(num):
    print(n, end=" ")
# Out:
# 3 1 2 6 5 3 1

# %% [markdown]
# #### While Loop with Condition

# %%
count = 0

while count < 5:
    if count == 3:
        print("Count is 3")
    count += 1
# Out:
# Count is 3
