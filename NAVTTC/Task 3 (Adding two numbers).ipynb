# %% [markdown]
# ## Adding 2 Numbers

# %%
import numpy as np
import pandas as pd
import cmath

# %%
num1 = 1.3
num2 = 6.5

#Add two numbers
sum = num1 + num2

#Display the sum
print('The Sum of {0} and {1} is {2}'.format(num1,num2,sum))
# Out:
# The Sum of 1.3 and 6.5 is 7.8
